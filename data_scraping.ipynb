# %% [markdown]
# <a href="https://colab.research.google.com/github/Sean1686/computer_vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food",
                    limit=100,
                    output_dir="/content/pilaf_image",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/pilaf_image/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://comicbook.com/wp-content/uploads/sites/4/2025/08/KPop-Demon-Hunters-Jinu.jpg?resize=1024
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 2
#
# [%] Indexed 25 Images on Page 2.
#
# ...
#
# [%] Downloading Image #2 from https://img.freepik.com/premium-photo/dark-neumorphic-user-interface-elements-with-neon-buttons-bars-black-neumorphism-style-dashboard-design-mobile-app-ui-kit-different-charts-week-statistics-template_551826-34741.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://cdn.dribbble.com/userupload/34130303/file/original-85ddbc0b26e460c52467902f52a4d920.png?resize=1600x1200
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://img.freepik.com/premium-photo/minimalist-dark-ui-app-design-vector-illustration_1273271-13622.jpg?w=1380
# [%] File Downloaded!
#
# ...

# %%
# !rm -rf /content/drive
# Out:
# rm: cannot remove '/content/drive/.shortcut-targets-by-id': Operation canceled
# rm: cannot remove '/content/drive/MyDrive': Operation canceled
# rm: cannot remove '/content/drive/.Trash-0': Directory not empty
# rm: cannot remove '/content/drive/.Encrypted/.shortcut-targets-by-id': Operation canceled
# rm: cannot remove '/content/drive/.Encrypted/MyDrive': Operation canceled

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, shutil

source_dir = '/content/pilaf_image/uzbek pilaf food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
downloader.download("kebab shashlik food",
                    limit=100,
                    output_dir="/content/kebab_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.licious.in/blog/wp-content/uploads/2020/12/Turkish-Kebabs-min.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://wallpaperaccess.com/full/10831705.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/f9/4d/9b/f94d9bc8f56d3d0302fc7e727947eb0d.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://www.thespruceeats.com/thmb/47Y9vapBkwe_98TIiueYFB3OObc=/2059x2059/filters:no_upscale():max_bytes(150000):strip_icc()/aIMG_0756fsq-5aebd1ddc0647100364ee63a.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://img.freepik.com/premium-photo/doner-kebab-doner-kebap-fast-food-meal-flatbread-with-fries-wooden-board_770123-5.jpg?w=2000
# [%] File Downloaded!
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, shutil

source_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
